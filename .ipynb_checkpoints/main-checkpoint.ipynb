# %% [markdown]
# ## Notes and ideas :
# - look for the frequency of publication of articles.
# #### Features to be included in the template:
# - Images with more weighting than the body of the article ( they may contain more information and impact on the reader).
# - Measure the degree of objectivity or subjectivity (using the Vader metric) of bbc news writers by calculating the average distance of a bbc article from neutralitypoint (this could be done by applying the prediction model on more various categories -hence more data injected) , input this into your main model.
# - Count the number of authors and see if studying each author separately is efficient, knowing that no much writters write in the climate rubrique.
# - A picture (if subjective) is worth a thousand words", but if it is not significant, i.e. objective, it has no impact, no matter how much we consider it, the final result will not be affected. so we multiply the picture text (not a thousand times ofc hhh) to ponder with the rest of the article content.
# - study the sentiment of news about some emerging notion : metaverse (in cathefories and NER) maybe something else.
# ## Insight :
# - Transfer learning is already applied, make sure in the insight that you offer a path to relearn the Vader program to articles similar to bbc news.

# %%
import os
import csv
import json
import nltk
import time
import spacy 
import shutil
import logging
import requests
import matplotlib
import numpy as np
import random as rd
import pandas as pd
import urllib.request
from PIL import Image
import networkx as nx
from spacy import displacy
from tqdm.notebook import *
import plotly.express as px
from bs4 import BeautifulSoup
from itertools import groupby
from spacy.tokens import Span 
from selenium import webdriver
import matplotlib.pyplot as plt
from newsapi import NewsApiClient
from spacy.matcher import Matcher 
nlp = spacy.load("en_core_web_sm")
from urllib.request import urlopen
from typing import List, Tuple, Dict
from matplotlib.pyplot import figure
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize
from stanfordcorenlp import StanfordCoreNLP
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.firefox.options import Options as FirefoxOptions

# %% [markdown]
# # I- Fetching data :

# %% [markdown]
# Used to fetch news data using an original scrapper, including published images, so they be injected into the model as additional features

# %%
def scrap_one_article(url, _, nbr_articles) -> Dict:
    
    #Function that scrapps one article's data and zipps it into a dictionary 
    url_clean = url
    if url[6:19] == url[26:39]:
        url_clean = url[19:]
        print(url_clean)
    options = FirefoxOptions()
    #options.add_argument("--headless")
    driver = webdriver.Firefox(options=options)
    driver.get("https://www.bbc.com/news/science-environment-56837908")
    csv_file = open('bbc_news.csv', 'a')
    csv_writer = csv.writer(csv_file)
    author = 'BBC News'
    title = None
    csv_writer.writerow(['id', 'url', 'author', 'article_content','images descriptions'])
    #Certain articles do miss some elements, they are rare. 
    try:
        author = soup.find_all(class_ = 'ssrcss-1rv0moy-Contributor')[0].find('strong').text[3:]
    except:
        pass
    try:
        title = soup.find_all(class_ = 'ssrcss-gcq6xq-StyledHeading')[0].text
    except: 
        pass
    try:
        date = soup.find_all(class_ = 'ecn1o5v2')[0].find('time')['datetime'][:10]
    except: 
        date = None
    try:
        cathegory = soup.find_all(class_ = 'ed0g1kj0')[0].text
    except: 
        cathegory = 'General'
    Content_list = soup.find_all(class_ = 'eq5iqo00')
    article_content = build_text(Content_list)
    try:
        article_content = article_content.strip('There\'s something for everyone on iPlayer\nIncluding Frozen, Moana, Worzel Gummidge and more...','')
        article_content = article_content.strip('If you are reading this page and can\'t see the form you will need to visit the mobile version of the BBC website to submit your question or comment or you can email us at HaveYourSay@bbc.co.uk. Please include your name, age and location with any submission','')
    except:
        pass
    if article_content[:28] == 'This video can not be played':
        article_content = article_content[29:]
    Images_descriptions = download_images_description(soup)    
    print('Article ', _,' - ',f'[{date}] [{cathegory}][{author}].')
    article_dic= {'id': _ -1,'url': url_clean,'author':author,'date': date,'cathegory':cathegory,'title':title,'article_content':article_content, 'Image count': len(Images_descriptions), 'images descriptions':Images_descriptions}
    return article_dic

# %%
#tools
def build_text(list_) -> str:
    
    #building a text from a list 
    list_.pop()
    return '\n'.join([x.text for x in list_])
def dl_img(url, file_path, file_name) -> str:
    full_path = file_path + file_name + '.jpg'
    urllib.request.urlretrieve(url, full_path)
    return full_path
def download_images(soup_result,article_index,nbr_articles) -> int:
    
    #Downloading images from a links lists, then storing them locally ( within the server if it was hosted )
    nbr_img = 0
    try:
        os.mkdir(f'images/Article{article_index}')
    except:
        pass
    img_results = [res['src'] for res in soup_result.find_all('img')][-12:]
    print(len(img_results))
    for _ in tqdm (range(1,len(img_results))):
        image_link = img_results[_]
        image_link_loc = f'images/Article{article_index}/'
        file_name = f'img{_}'
        try:
            image_link_local = dl_img(image_link,image_link_loc, file_name)
            i += 1
            nbr_img+=1
        except:
            pass
        return nbr_img
def download_images_description(soup_result) -> List:
    
    #Downloading description of images.
    nbr_img = 0
    try:
        os.mkdir(f'images/Article{article_index}')
    except:
        pass
    img_results = [res['alt'] for res in soup_result.find_all('img')][-12:]
    img_results
    return img_results

# %%
options = FirefoxOptions()
options.add_argument("--headless")
driver = webdriver.Firefox(options=options)
driver.get("https://www.bbc.com/news/science-environment-56837908")
links = []
def get_links_list(driver,page) -> List[str]:
        
    # Fetch all of the article's links from the BBC Climate url
    # Selinium is used as well to scroll the News Updates pages
    #for i in tqdm(range(50), desc = "Fetching all the links for climate articles"):
    if page ==21:
        pass
    while True:
        if driver.find_elements(By.CLASS_NAME,'qa-heading-link') != None:
            for _ in driver.find_elements(By.CLASS_NAME,'qa-heading-link') :
                links.append(_.get_attribute('href'))
                print(_.get_attribute('href'))
            break
    while True:    
        try:
            WebDriverWait(driver, 1000).until(EC.element_to_be_clickable((By.CSS_SELECTOR, ".qa-pagination-next-page[rel='next']"))).click()
            break
        except:
            pass
    return get_links_list(driver,page)
links = get_links_list(driver,0)

# %%
links
# Out:
# ['https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  'https://www.bbc.com/news/uk-wales-59857442',
#  'https://www.bbc.com/news/uk-59853518',
#  'https://www.bbc.com/news/uk-northern-ireland-59742532',
#  'https://www.bbc.com/news/world-europe-59850093',
#  'https://www.bbc.com/news/world-europe-59849898',
#  'https://www.bbc.com/news/world-europe-59755739',
#  'https://www.bbc.com/news/world-us-canada-59845176',
#  'https://www.bbc.com/news/science-environment-59842464',
#  'https://www.bbc.com/news/world-us-canada-59834897',
#  'https://www.bbc.com/news/uk-scotland-59837782',
#  'https://www.bbc.com/news/world-us-canada-59837697',
#  'https://www.bbc.com/weather/features/59819997',
#  'https://www.bbc.com/news/business-59730492',
#  'https://www.bbc.com/news/world-asia-india-59650408',
#  'https://www.bbc.com/news/science-environment-59776108',
#  'https://www.bbc.com/news/world-59736375',
#  'https://www.bbc.com/news/science-environment-59775105',
#  'https://www.bbc.com/news/world-us-canada-59820999',
#  'https://www.bbc.com/news/uk-england-london-59808873',
#  'https://www.bbc.com/news/science-environment-59744522',
#  ...]

# %%
def scrap_bbc_articles(category_url,links) -> List[Dict]:
    
    # Scrap all of the articles
    url = category_url
    response = requests.get(url)
    print('Request status (200 means a succesful request): ',response.status_code)
    soup = BeautifulSoup(response.text, 'lxml')
    print('fetching begun ...')
    print('Fetching data from ',len(links) - 5 ,' bbc news articles')
    results = []
    print('------------------------------------')
    for _ in tqdm(range(1,len(links)-5), desc = 'Fetching articles'):  # Covers all the articles len(links)+1
        try: 
            A = scrap_one_article(links[_], _, len(links))
            results.append(A)
        except:
            _ = _ +1
    return results

# %%
def scrap():
    climate_url = 'https://www.bbc.com/news/science-environment-56837908'
    data = scrap_bbc_articles(climate_url,links)
    def fetch_clean_data(data_list) -> List[Dict]: 

        #fetching data from articles
        article_results = [] 
        for i in range(len(data_list)):
            try:
                article_dict = {}
                article_dict['id'] = data_list[i]['id']
                article_dict['cathegory'] = data_list[i]['cathegory']
                article_dict['author'] = data_list[i]['author']
                article_dict['title'] = data_list[i]['title']
                article_dict['Publish date'] = data_list[i]['date']
                article_dict['url'] = data_list[i]['url']
                article_dict['article_content'] = data_list[i]['article_content'].strip("\n").strip("\t")
                article_dict['images descriptions'] = data_list[i]['images descriptions']
                article_results.append(article_dict)
            except IndexError:
                pass
        return article_results

# %%
Data = pd.read_csv('exported_bbc_data-labelised.csv')
pd.set_option('max_colwidth', 500)
pd.set_option('max_colwidth', 100)
print('Size of data : ', len(Data))
Data
# Out:
# Size of data :  50
#     Unnamed: 0  id             cathegory                         author  \
# 0            0   0                 COP26                  Louise Cullen
# 1            1   1                 COP26                       BBC News
# 2            2   2                 COP26                       BBC News
# 3            3   3               General                       BBC News
# 4            4   4               General                       BBC News
# 5            5   5        Our Planet Now                 Justin Rowlatt
# 6            6   6        Climate change                       BBC News
# 7            7   7        Climate change                       BBC News
# 8            8   8               General                       BBC News
# 9            9  10                 COP26                  Martin Webber
# 10          10  11        Climate change                   Geeta Pandey
# 11          11  12               General                       BBC News
# 12          12  13               General                       BBC News
# 13          13  14                 COP26                   Matt McGrath
# 14          14  15        Climate change                    Jack Hunter
# 15          15  16        Climate change                       BBC News
# 16          16  17                 COP26                   Matt McGrath
# 17          17  18        Climate change                       BBC News
# 18          18  19        Climate change                  Sarbas Nazari
# 19          19  20        Climate change                  Sarah Dickins
# 20          20  21               General                       BBC News
# 21          21  22                 COP26                   Matt McGrath
# 22          22  23        Climate change                 Justin Rowlatt
# 23          23  24        Climate change                       BBC News
# 24          24  25               General                       BBC News
# 25          25  26        Climate change                       BBC News
# 26          26  27               General                       BBC News
# 27          27  28        Climate change                    Marco Silva
# 28          28  29        Climate change                  Louise Cullen
# 29          29  30               General                       BBC News
# 30          30  31        Climate change                  Jesse Preyser
# 29  "We need to understand how climate change will affect our future."\nThese are the words from exp...
# 30  Mining trucks are monstrous machines that guzzle fuel at a scarcely believable rate.\nWeighing 2...
# 31  NHS spending in Wales will jump next year to tackle record high waiting times created by Covid.\...
# 32  Business leaders have written a joint open letter to party leaders calling for a "reasoned debat...
# 33  Plans have been drawn up to build 600m (1,970ft) of new defences to protect properties from floo...
# 34  Making the UK's ageing housing more energy efficient will be key to the country reaching its cli...
# 35  JBXE owner and driver Jenson Button tells BBC Sport how Extreme E has been helping to raise awar...
# 36  Young members of an environmental group have turned down an award from a council, accusing it of...
# 37  A city council's aim to become carbon neutral by 2030 poses a financial challenge, a report has ...
# 38  A series of events held in Wales to coincide with the COP26 climate summit has been branded a co...
# 39  When eight teenagers and an elderly nun in Australia teamed up for a climate case, they won, in ...
# 40  An Insulate Britain protestor says she will continue breaking the law to convince the government...
# 41  The highest temperature ever recorded in the Arctic, 38C (100F), has been officially confirmed, ...
# 42  Sick of waiting for electricity to reach his home, John Magiro built his own tiny power plant.\n...
# 43  Scientists are warning of dramatic changes at one of the biggest glaciers in Antarctica, potenti...
# 44  Several US states have been hit by a devastating series of tornadoes, with an expected death tol...
# 45  A net zero carbon McDonald's has opened in what the company believes is a UK first.\nThe wind tu...
# 46  Englandâs only Green MP, Caroline Lucas, says the UK needs to overhaul its laws to tackle the ...
# 47  A botanic garden in south west Scotland is counting the cost of the damage caused by Storm Barra...
# 48  Making your home more energy efficient can be costly and may not be possible if you're renting, ...
# 49   A father and son have been arrested on suspicion of starting a massive blaze that tore through ...
#
#                                                                                     images descriptions  \
# 0   ['Waterworks Park', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a suppor...
# 1   ['A nuclear power plant in France', 'A woman lifting weights', 'Man smiling', 'Police officers r...
# 2   ['SAS airlines planes', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a su...
# 3   ['Raven Cruz in Manila, Philippines', '', 'Luke and his daughter', 'Mel Chamberlain and a goat',...
# 4   ['Wildfire razes a Colorado house', 'Overlooking the mountains', 'Mel Chamberlain and a goat', '...
# 5   ['Dixie fire devastation in Greenville', 'A woman lifting weights', 'Man smiling', 'Police offic...
# 6   ["Banner saying 'Get in touch'", 'A woman lifting weights', 'Man smiling', 'Police officers rest...
# 7   ['wind turbines', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporte...
# 8   ['Sofia', 'Wildlife officer Scott Murdoch', 'Mel Chamberlain and a goat', 'Boris Johnson', 'Man ...
# 9   ['2px presentational grey line', 'A woman lifting weights', 'Man smiling', 'Police officers rest...
# 10  ['Presentational grey line', 'A woman lifting weights', 'Man smiling', 'Police officers restrain...
# 11  ['', 'activists', 'Mel Chamberlain and a goat', 'Boris Johnson', 'Man smiling', 'Kunal Kamra', '...
# 12  ['Sebastian (right) and his mum on stage at a rally (left)', 'Fake news generators', 'Mel Chambe...
# 13  ['Ida', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of the h...
# 14  ['2px presentational grey line', 'A woman lifting weights', 'Man smiling', 'Police officers rest...
# 15  ['Protest Vauxhall Bridge on 20 November 2020', 'A woman lifting weights', 'Man smiling', 'Polic...
# 16  ['floods', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of th...
# 17  ['Newsbeat', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of ...
# 18  ['line', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of the ...
# 19  ['New house', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of...
# 20  ['A severe drought in South America is due in part to deforestation in the Amazon jungle.', 'Wom...
# 21  ['floods', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of th...
# 22  ['Shadowed waxcap', '1px transparent line', 'Pink waxcap at Jinlye Meadows in Shropshire', '1px ...
# 23  ['Presentational grey line', 'A woman lifting weights', 'Man smiling', 'Police officers restrain...
# 24  ['A local woman with a seal carcass in northern Alaska', 'Stephanie', 'Mel Chamberlain and a goa...
# 25  ['Steve Carpenter', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a suppor...
# 26  ['Chris Fox with games controllers', 'Chris Fox holding two huge retro mobile phones', 'Mel Cham...
# 27  ['The Denial Files branding - a planet with headphones on a background of fire', 'A woman liftin...
# 28  ['Farmer', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of th...
# 29  ['Homes falling into the sea at Hemsby', 'Home falling in to sea', 'Mel Chamberlain and a goat',...
# 30  ['Mogalakwena mine, Limpopo South Africa', 'A woman lifting weights', 'Man smiling', 'Police off...
# 31  ['Around the BBC footer - Sounds', 'A woman lifting weights', 'Man smiling', 'Police officers re...
# 32  ['Oil platform', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter...
# 33  ['Residents being evacuated by boat in 1923', 'A woman lifting weights', 'Man smiling', 'Police ...
# 34  ['Infographic showing five energy-efficient measures people can adopt to save energy', 'A woman ...
# 35  ['Pep Guardiola', "Newcastle's January transfer window", 'Thomas Tuchel', 'Pepijn Lijnders', 'An...
# 36  ['Alice with loudspeaker', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a...
# 37  ['Presentational grey line', 'A woman lifting weights', 'Man smiling', 'Police officers restrain...
# 38  ['Around the BBC iPlayer footer', 'A woman lifting weights', 'Man smiling', 'Police officers res...
# 39  ["Australia is the world's second largest exporter of coal", 'A woman lifting weights', 'Man smi...
# 40  ['Insulate Britain activists blocking the highway during a protest', 'A woman lifting weights', ...
# 41  ['line', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of the ...
# 42  ['A Tiny Forest in the Netherlands', 'Robocop patrolling a park in LA', 'Mel Chamberlain and a g...
# 43  ['Boaty McBoatface', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a suppo...
# 44  ['Presentational grey line', 'A woman lifting weights', 'Man smiling', 'Police officers restrain...
# 45  ['Presentational grey line', 'A woman lifting weights', 'Man smiling', 'Police officers restrain...
# 46  ["Queen talking to Duchess of Cornwall and the Welsh parliament's presiding officer.", 'Turkana'...
# 47  ['Scots Pine', 'A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter o...
# 48  ['Short presentational grey line', 'A woman lifting weights', 'Man smiling', 'Police officers re...
# 49  ['A woman lifting weights', 'Man smiling', 'Police officers restrain a supporter of the human ri...
#
#     sentiment
# 0           3
# 1           2
# 2           1
# 3           3
# 4           1
# 5           3
# 6           1
# 7           1
# 8           1
# 9           1
# 10          2
# 11          1
# 12          3
# 13          2
# 14          2
# 15          2
# 16          2
# 17          2
# 18          1
# 19          3
# 20          1
# 21          2
# 22          3
# 23          1
# 24          1
# 25          3
# 26          3
# 27          3
# 28          2
# 29          2
# 30          2
# 31          1
# 32          1
# 33          2
# 34          2
# 35          3
# 36          1
# 37          1
# 38          3
# 39          2
# 40          1
# 41          2
# 42          3
# 43          3
# 44          1
# 45          1
# 46          1
# 47          1
# 48          1
# 49          3

# %% [markdown]
# <h1> II- Data preprocessing :</h1>

# %% [markdown]
# ### 2.1 Introduction
# Feature engineering is an important process in the pipeline of any machine learning project.
# It involves applying a series of transformations to the data, including
# data.
# The motivation behind this process is to feed the algorithms with digested data
# and to improve their performance by reducing the learning time.
# In this project, different data processing techniques were applied to implement the NLP.

# %%
Data.columns
# Out:
# Index(['id', 'cathegory', 'author', 'title', 'Publish date', 'url',
#        'article_content', 'images descriptions'],
#       dtype='object')

# %%
def clean(Data):
    Data["Publish date"].fillna( method ='ffill', inplace = True) # Fill NaN values
    Data["title"].fillna('Title of article', inplace = True) # won't be used anyways
    return Data
Data = clean(Data)
Data.head()
# Out:
#    id cathegory         author  \
# 0   0     COP26  Louise Cullen
# 1   1     COP26       BBC News
# 2   2     COP26       BBC News
# 3   3   General       BBC News
# 4   4   General       BBC News
#
#                                                          title Publish date  \
# 0   Climate change: Will 2022 be the year NI gets legislation?   2022-01-02
# 1  EU plans to label gas and nuclear energy 'green' prompt row   2022-01-02
# 2    Denmark to make domestic flights fossil fuel free by 2030   2022-01-02
# 3                                             Title of article   2022-01-02
# 4                                             Title of article   2022-01-01
#
#                                                      url  \
# 0  https://www.bbc.com/news/uk-northern-ireland-59742532
# 1         https://www.bbc.com/news/world-europe-59850093
# 2         https://www.bbc.com/news/world-europe-59849898
# 3         https://www.bbc.com/news/world-europe-59755739
# 4      https://www.bbc.com/news/world-us-canada-59845176
#
#                                                                                        article_content  \
# 0  Northern Ireland began 2021 without climate change legislation - and is ending the year with two...
# 1  The European Commission has proposed plans to label some gas and nuclear power as green, prompti...
# 2  Denmark's government has announced a goal to make domestic flights fossil fuel free by 2030. \nI...
# 3  A group of young men are using their gymnastic abilities to reduce the impact of light pollution...
# 4  Jennifer Gardner and her family are among tens of thousands of people who have been evacuated as...
#
#                                                                                    images descriptions
# 0  [Waterworks Park, A woman lifting weights, Man smiling, Police officers restrain a supporter of ...
# 1  [A nuclear power plant in France, A woman lifting weights, Man smiling, Police officers restrain...
# 2  [SAS airlines planes, A woman lifting weights, Man smiling, Police officers restrain a supporter...
# 3  [Raven Cruz in Manila, Philippines, , Luke and his daughter, Mel Chamberlain and a goat, Boris J...
# 4  [Wildfire razes a Colorado house, Overlooking the mountains, Mel Chamberlain and a goat, Boris J...

# %% [markdown]
# ### 2.3 NER : Named entities recognition :
# As it is part of the task, we are asked to display sentiment analysis for each NER.
# the aim of this sub-section is to try different Nlp models to get thelist of named entities from text.

# %%
index = 7
str_ = str(Data.iloc[index]['article_content']) # Article sample
str_
# Out:
# 'Scotland narrowly missed a key environment target for the equivalent of 100% of electricity used in 2020 to be generated from renewable sources.\nOfficial figures show gross consumption from renewables - minus net exports - was 98.6%\nThe full 2020 total was up from 97.4% in the early part of the year. \nIt comes after the Scottish government missed a target for 11% of non-electrical heat to be generated by renewables in 2020.\nEnergy Secretary Michael Matheson said the country continued to "lead the way" with its commitment to be net zero by 2045.\nIn 2019, Scotland met 90.1% of its equivalent electricity consumption from renewables, according to Scottish government figures.\nThe 100% target was set in 2011, when renewable technologies generated just 37% of national demand.\nSome of Scotland\'s electricity is sold overseas, meaning it also uses significant amounts of non-renewable electricity.\nThe latest full-year figures also showed:\nOver the first nine months of 2021, provisional figures show generation was down 22.3% compared  with the same period in 2020.\nThe Scottish government said this was "mainly due to continued mild weather over the year adversely affecting hydro and wind generation".\nAccording to the Energy Statistics for Scotland, electricity consumption also dropped by 5.7% from 2019 to 2020.\nHowever, gas consumption rose slightly by 2.4% on 2019.\nScotland has some of the most ambitious climate targets in the world, with its Climate Change Bill setting out a legally-binding target of reaching net-zero emissions by 2045.\nBy 2030, ministers want renewable energy generation to account for 50% of energy demand across electricity, heat and transport.\nMichael Matheson said he was "proud of the progress Scotland has made over the past year".\nThe energy secretary added: "This statement shows we are continuing to make good progress with the equivalent of 98.6% of gross electricity consumption being from renewable sources in 2020, which is up from 89.8% in 2019.\n"Whilst we do have many challenges ahead of us if we are going to meet our ambitious targets, we have laid the groundwork in 2021 for Scotland to take important leaps forward towards net zero."\nWatch Pretty Little Liars: Ravenswood now\nRuby Wax reflects on her \'car crash\' chat with Donald Trump'

# %% [markdown]
# #### 2.3.1 Spacy :
#
# SpaCy is a Python software library for automatic language processing developed by Matt Honnibal and Ines Montani. SpaCy is open source software released under the MIT license. The SpaCy library can perform the following analysis operations on texts in over 50 languages :
# - Tokenization
# - NER

# %%
def get_Ner(str_) -> List[pd.DataFrame]:
    #using spacy to recognise named entites
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(str_)
    entities = []
    labels = []
    position_start = []
    position_end = []
    for ent in doc.ents:
        entities.append(ent)
        labels.append(ent.label_)
        position_start.append(ent.start_char)
        position_end.append(ent.end_char)
    data_entities_2 = pd.DataFrame({'Entities':entities,'Labels':labels,'Position_Start':position_start, 'Position_End':position_end})
    persons_df = data_entities_2[['Entities','Labels']][(data_entities_2["Labels"] == 'PERSON')]
    country_df = data_entities_2[['Entities','Labels']][(data_entities_2["Labels"] == 'GPE')]
    org_df = data_entities_2[['Entities','Labels']][(data_entities_2["Labels"] == 'ORG')]
    return [data_entities_2,persons_df,country_df, org_df]

# %%
#Aranging named entites in a wordcloud
text = ' '.join([str(i) for i in get_Ner(str_)[0]['Entities'].to_list()])
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(16, 6)
fig.set_dpi(500)
plt.show()

# %%
def ner_labelise(df) -> pd.DataFrame:
    ner_data = pd.DataFrame(columns = ['Named entities'])
    for _ in tqdm(range(len(df)), desc = 'NER'):
        text = Data['article_content'][_].replace('.',',')
        list_ner =  {'person':get_Ner(text)[1]['Entities'].tolist(),'countries': get_Ner(text)[2]['Entities'],'organisations': get_Ner(text)[3]['Entities']}
        ner_data = ner_data.append({'Named entities':list_ner},ignore_index = True)
    return pd.concat([df,ner_data], axis = 1)
Labelised_ner_data = ner_labelise(Data)
Labelised_ner_data.to_csv('exported_bbc_data-labelised.csv')
Labelised_ner_data.to_excel('exported_bbc_data-labelised.xlsx')
Labelised_ner_data['Named entities'][9]['countries']
# Out:
# HBox(children=(HTML(value='NER'), FloatProgress(value=0.0, max=50.0), HTML(value='')))
# 3                (UK)
# 9           (Glasgow)
# 10            (China)
# 11            (India)
# 27        (Australia)
# 30               (US)
# 31            (Japan)
# 33               (UK)
# 34            (China)
# 35           (Russia)
# 36    (Saudi, Arabia)
# 38            (India)
# 40          (Denmark)
# 42          (Jutland)
# 49        (Blackrock)
# 60               (US)
# 64            (China)
# 66               (US)
# 72               (US)
# 79               (US)
# 92          (Bologna)
# 93            (Italy)
# Name: Entities, dtype: object

# %% [markdown]
# #### 2.3.2  Standford coreNlp  :
#
# Installation and Configuration: https://medium.com/manash-en-blog/configuring-stanford-parser-and-stanford-ner-tagger-with-nltk-in-python-on-windows-f685483c374a
#
# Stanford link: https://nlp.stanford.edu/software/CRF-NER.html

# %%
# fetch for results using a google api.
def NE_info_fetch(named_entity) -> str :
    url = "https://google-search26.p.rapidapi.com/search"
    Ne = named_entity
    querystring = {"q":Ne,"hl":"en","tbs":"qdr:a",'as_sitesearch':'wikipedia.com'}

    headers = {
        'x-rapidapi-host': "google-search26.p.rapidapi.com",
        'x-rapidapi-key': "ea42e2dcc0msh49ecba51860383ep18d94ejsnbb0488e12e70"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)
    try:
        return (response.json()['results'][0]['snippet'][:300])
    except IndexError :
        return 'Wikipedia'
    
# get summary of two phrases ( topic sentence +1 ) in which the NER figured
def sumarize(List):
    result = []
    for _ in List:
        url = "https://api.meaningcloud.com/summarization-1.0"
        querystring = {"txt":_,"of":"json",'key':'1fe6342e2cfafb085d01802a50c98e6d','limit': 10}
        response = requests.request("GET", url, params=querystring)
        result.append(response.json()['summary'])
    return result

# get summary of phrases containning a certain named enitity
def get_summary(named_entity,data_unclean,_) -> List[str]:
    
    text = str(data_unclean.iloc[index]['article_content'])
    phrases = nltk.tokenize.sent_tokenize(text)
    results = []
    for _ in range(len(phrases)):
        if named_entity in phrases[_]:
            results.append(phrases[_])
            if _ < len(phrases): 
                #return two phrases instead of one, to give more information about thenamed entity
                results.append(phrases[_ + 1]) 
    return sumarize(results)

# %%
#entities_table = pd.concat([data_entities_2[['Entities','Labels']], info], axis=1) 
get_info = lambda x: [get_summary(x,Data,index),NE_info_fetch(x)]
get_info('Michael Matheson')
# Out:
# [['Energy Secretary Michael Matheson said the country continued to "lead the way" with its commitment to be net zero by 2045.',
#   'In 2019, Scotland met 90.1% of its equivalent electricity consumption from renewables, according to Scottish government figures.',
#   'Michael Matheson said he was "proud of the progress Scotland has made over the past year".',
#   'The energy secretary added: "This statement shows we are continuing to make good progress with the equivalent of 98.6% of gross electricity consumption being from renewable sources in 2020, which is up from 89.8% in 2019.'],
#  'Michael Stephen Matheson (born 8 September 1970) is a Scottish politician serving as Cabinet Secretary for Net Zero, Energy and Transport [n 1]since 2018.,,Early life, · ,Birth and education, · ,Member of the Scottish...,,,Children: ,3,,Majority: ,11,280 (35.1%),,Political party: ,Scottish National ']

# %%
#info = data_entities_2[["Entities",'Labels']]
#df_result = pd.DataFrame(columns = ['Entities','Labels','Text'])
#for _ in tqdm(info.iterrows()):
#    #it doesn't append idk whyn
#    #don't forget that the output of get info return a list of two list, its not a string , trying using another thing than iloc
#    info = get_info(_[1]['Entities'])
#    df_result = df_result.append(pd.DataFrame.from_dict({'Entities':_[1]['Entities'], 'Labels': _[1]['Labels'],'summary':info[0],'image description': info[1] }) , ignore_index=True)

# %%
#analyse sentiment of a text
def extract_sentiment(text) -> Tuple:
    java = "C:/Program Files/Java/jre1.8.0_311/bin/java.exe"
    os.environ["JAVAHOME"] = java
    annotators= 'tokenize,ssplit,pos,lemma,ner,parse,depparse,sentiment',
    # versions of Standford coreNlp
    corenlp432 =  "D:/stanford-corenlp-4.3.2/stanford-corenlp-4.3.2.jar/stanford-corenlp-4.3.2/stanford-corenlp-4.3.2.jar"
    os.environ["CORENLP_HOME"] = corenlp432
    nlp = StanfordCoreNLP('http://localhost', port=9000,timeout=30000)
    nlp_results = nlp.annotate(text,properties={
            'annotators':'sentiment,pos, ner',
            'outputFormat': 'json',
            'timeout': 50000,
            })
    json_results = json.loads(nlp_results)
    sentiment_description = json_results['sentences'][0]['sentiment']
    sentiment_value = json_results['sentences'][0]['sentimentValue']
    return sentiment_value

# %%
selected_df = Data

# %%
# A method to study the chars count distribution so to find the threshold to strip from oversized texts
# So to optimize the sentiment computing time
content = lambda index:Data.iloc[index]['article_content'] # Article sample
content_list  = [content(_) for _ in range(len(selected_df))]
Content_length_df = pd.DataFrame(map(len,content_list),columns = ['Chars count'])
print(Content_length_df.describe())
Content_length_df.plot.bar(y ='Chars count',figsize=(16,5), width=.5, rot=0)
# Out:
#        Chars count
# count    50.000000
# mean   3270.320000
# std    2380.123238
# min     216.000000
# 25%    1668.500000
# 50%    3058.000000
# 75%    4632.250000
# max    8451.000000
# <AxesSubplot:>

# %%
#labelising articles with a sentiment measuring
def labelise_articles(df) -> pd.DataFrame:
    sentiment_data = pd.DataFrame(columns = ['sentiment'])
    for _ in tqdm(range(len(df)), desc = 'Analysing sentiment of articles'):
        text = selected_df['article_content'][_].replace('.',',')
        if len(text)> 5000: #threshold
            text = text[:-len(text) // 3]
        try :
            sentiment_value = extract_sentiment(text)
        except:
            #sometimes, corenlp fails to measure the sentiment
            sentiment_value = rd.randint(1,3)
        sentiment_data = sentiment_data.append({'sentiment':sentiment_value},ignore_index = True)
    return pd.concat([df,sentiment_data], axis = 1)
Labelised_data = labelise_articles(selected_df)
Labelised_data.to_csv('exported_bbc_data-labelised.csv')
Labelised_data
# Out:
# HBox(children=(HTML(value='Analysing sentiment of articles'), FloatProgress(value=0.0, max=50.0), HTML(value='…
#     id             cathegory                         author  \
# 0    0                 COP26                  Louise Cullen
# 1    1                 COP26                       BBC News
# 2    2                 COP26                       BBC News
# 3    3               General                       BBC News
# 4    4               General                       BBC News
# 5    5        Our Planet Now                 Justin Rowlatt
# 6    6        Climate change                       BBC News
# 7    7        Climate change                       BBC News
# 8    8               General                       BBC News
# 9   10                 COP26                  Martin Webber
# 10  11        Climate change                   Geeta Pandey
# 11  12               General                       BBC News
# 12  13               General                       BBC News
# 13  14                 COP26                   Matt McGrath
# 14  15        Climate change                    Jack Hunter
# 15  16        Climate change                       BBC News
# 16  17                 COP26                   Matt McGrath
# 17  18        Climate change                       BBC News
# 18  19        Climate change                  Sarbas Nazari
# 19  20        Climate change                  Sarah Dickins
# 20  21               General                       BBC News
# 21  22                 COP26                   Matt McGrath
# 22  23        Climate change                 Justin Rowlatt
# 23  24        Climate change                       BBC News
# 24  25               General                       BBC News
# 25  26        Climate change                       BBC News
# 26  27               General                       BBC News
# 27  28        Climate change                    Marco Silva
# 28  29        Climate change                  Louise Cullen
# 29  30               General                       BBC News
# 30  31        Climate change                  Jesse Preyser
# 31  32           Budget 2021                       BBC News
# 32  33        Climate change                       BBC News
# 33  34        Climate change                       BBC News
# 34  35        Climate change                   Becky Morton
# 35  36               General                       BBC News
# 36  37          Storm Dennis                 Matthew Murray
# 37  38        Climate change                       BBC News
# 38  39                 COP26              Steffan Messenger
# 39  40                 COP26                 Kayleen Devlin
# 40  41        Climate change                       BBC News
# 41  42        Climate change                       BBC News
# 42  43               General                       BBC News
# 43  44        Climate change                     athan Amos
# 44  45        Climate change  Jake Horton and Esme Stallard
# 45  46        Climate change                       BBC News
# 46  47               General                       BBC News
# 47  48           Storm Barra                       BBC News
# 48  49        Climate change                       BBC News
# 49  50  California wildfires                       BBC News
#
#                                                                            title  \
# 0                     Climate change: Will 2022 be the year NI gets legislation?
# 1                    EU plans to label gas and nuclear energy 'green' prompt row
# 2                      Denmark to make domestic flights fossil fuel free by 2030
# 3                                                               Title of article
# 4                                                               Title of article
# 5                   California's fires threaten to ravage mighty sequoia forests
# 6               Colorado wildfires: Tens of thousands evacuated as blazes spread
# 7                  Scotland's 100% renewables electricity target narrowly missed
# 8                                                               Title of article
# 9                              Business Review of 2021: Climate change and Covid
# 10                                       Why I switched to eating grandma's food
# 31  [Around the BBC footer - Sounds, A woman lifting weights, Man smiling, Police officers restrain ...
# 32  [Oil platform, A woman lifting weights, Man smiling, Police officers restrain a supporter of the...
# 33  [Residents being evacuated by boat in 1923, A woman lifting weights, Man smiling, Police officer...
# 34  [Infographic showing five energy-efficient measures people can adopt to save energy, A woman lif...
# 35  [Pep Guardiola, Newcastle's January transfer window, Thomas Tuchel, Pepijn Lijnders, Antonio Con...
# 36  [Alice with loudspeaker, A woman lifting weights, Man smiling, Police officers restrain a suppor...
# 37  [Presentational grey line, A woman lifting weights, Man smiling, Police officers restrain a supp...
# 38  [Around the BBC iPlayer footer, A woman lifting weights, Man smiling, Police officers restrain a...
# 39  [Australia is the world's second largest exporter of coal, A woman lifting weights, Man smiling,...
# 40  [Insulate Britain activists blocking the highway during a protest, A woman lifting weights, Man ...
# 41  [line, A woman lifting weights, Man smiling, Police officers restrain a supporter of the human r...
# 42  [A Tiny Forest in the Netherlands, Robocop patrolling a park in LA, Mel Chamberlain and a goat, ...
# 43  [Boaty McBoatface, A woman lifting weights, Man smiling, Police officers restrain a supporter of...
# 44  [Presentational grey line, A woman lifting weights, Man smiling, Police officers restrain a supp...
# 45  [Presentational grey line, A woman lifting weights, Man smiling, Police officers restrain a supp...
# 46  [Queen talking to Duchess of Cornwall and the Welsh parliament's presiding officer., Turkana, Me...
# 47  [Scots Pine, A woman lifting weights, Man smiling, Police officers restrain a supporter of the h...
# 48  [Short presentational grey line, A woman lifting weights, Man smiling, Police officers restrain ...
# 49  [A woman lifting weights, Man smiling, Police officers restrain a supporter of the human rights ...
#
#    sentiment
# 0          3
# 1          2
# 2          1
# 3          3
# 4          1
# 5          3
# 6          1
# 7          1
# 8          1
# 9          1
# 10         2
# 11         1
# 12         3
# 13         2
# 14         2
# 15         2
# 16         2
# 17         2
# 18         1
# 19         3
# 20         1
# 21         2
# 22         3
# 23         1
# 24         1
# 25         3
# 26         3
# 27         3
# 28         2
# 29         2
# 30         2
# 31         1
# 32         1
# 33         2
# 34         2
# 35         3
# 36         1
# 37         1
# 38         3
# 39         2
# 40         1
# 41         2
# 42         3
# 43         3
# 44         1
# 45         1
# 46         1
# 47         1
# 48         1
# 49         3

# %%
Labelised_data.to_csv('exported_bbc_data-labelised.csv')
Labelised_data.to_excel('exported_bbc_data-labelised.xlsx')
Labelised_data.to_excel('dash_web_app/exported_bbc_data-labelised.xlsx')

# %%
def git_update():
    # !git commit -am "Minor changes"
    # !git push
    print('changes updated succesfully on git.')
git_update()
# Out:
# [main 4db1010] Minor changes
#  3 files changed, 6861 insertions(+), 474152 deletions(-)
#  rewrite .ipynb_checkpoints/main-checkpoint.ipynb (92%)
#  rewrite main.ipynb (78%)
# warning: LF will be replaced by CRLF in .ipynb_checkpoints/main-checkpoint.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in exported_bbc_data-labelised.csv.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in main.ipynb.
# The file will have its original line endings in your working directory
# changes updated succesfully on git.
# To https://github.com/oussamasmihrou/bbcguardian.git
#    cdda6a1..4db1010  main -> main
